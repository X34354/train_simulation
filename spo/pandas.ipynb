# %%
#instalacion
# !pip install pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('pandas1.PNG')
imgplot = plt.imshow(img)
plt.show()

# %%
#create dataframe
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

datafra = pd.DataFrame(data)

# %%
datafra
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
dataf = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])

dataf
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
dataf.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
dataf.to_csv('prueba.csv')

# %%
#leemos el csv
dataf = pd.read_csv('prueba.csv')

# %%
dataf
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
dataf.set_index('Unnamed: 0')
# Out:
#             apples  oranges
# Unnamed: 0
# June             3        0
# Robert           2        3
# Lily             0        7
# David            1        2

# %%
#leemos un csv mas interesante
data = pd.read_csv('kc_house_data.csv')

# %%
data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
#vamos los nombres de las columnas
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#veamos las dimensiones del dataframe (ya que lo podemos ver como una matriz)
data.shape
# Out:
# (21613, 21)

# %%
#operaciones basicas que se puede hacer en un dataframe

# %%
#seleccion de una columna
columna = data['price']

# %%
columna
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
#podemos borrar esa columna al dataframe original 
del  data['price']

# %%
data.shape
# Out:
# (21613, 20)

# %%
data = pd.read_csv('kc_house_data.csv')

# %%
data.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21608  False  False  False     False      False        False     False
# 21609  False  False  False     False      False        False     False
# 21610  False  False  False     False      False        False     False
# 21611  False  False  False     False      False        False     False
# 21612  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (21613, 21)

# %%
df = data[0:5]

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.shape
# Out:
# (5, 21)

# %%
#podemos añadir una columna nueva
df['mascara'] = True
# Out:
# C:\Users\fraja\AppData\Local\Temp\ipykernel_33760\408748410.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mascara'] = True

# %%
df.shape
# Out:
# (5, 22)

# %%
df
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#podemos filtrar por condiciones 
df2 = data[data['bathrooms'] == 2]

# %%
df2.head()
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 4   1954400510  20150218T000000  510000.0         3        2.0         1680
# 14  1175000570  20150312T000000  530000.0         5        2.0         1810
# 16  1875500060  20140731T000000  395000.0         3        2.0         1890
# 25  1202000200  20141103T000000  233000.0         3        2.0         1710
# 37  2768000400  20141230T000000  640000.0         4        2.0         2360
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 4       8080     1.0           0     0  ...      8        1680              0
# 14      4850     1.5           0     0  ...      7        1810              0
# 16     14040     2.0           0     0  ...      7        1890              0
# 25      4697     1.5           0     0  ...      6        1710              0
# 37      6000     2.0           0     0  ...      8        2360              0
#
# ...
